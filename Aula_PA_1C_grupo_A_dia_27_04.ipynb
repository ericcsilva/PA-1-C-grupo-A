# %% [markdown]
# <a href="https://colab.research.google.com/github/ericcsilva/PA-1-C-grupo-A/blob/main/Aula_PA_1C_grupo_A_dia_27_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# inteiraçoes e laços de repetiçao

print ('ola Mundo')
print ('ola Mundo')
print ('ola Mundo')
print ('ola Mundo')
print ('ola Mundo')

# %%
for i in rage (5):
  print ('ola mundo')

# %%
for i in range (5):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (1,6):
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# escrever um programa que print de 5 ate 0
for i in range (7):
  print (6 - i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# escrever um programa que print os numeros pares de 0 a 10
for i in range (0, 11, 2):
   print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# opçao 2
for i in range (11):

 if i % 2 == 0:
  print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# print numeros impares
for i in range (1, 11, 2):
   print (i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# escrever um programa que o usuario digita um numero de 1 a 10 e print a tabuada

numero = int(input("digite um numero: "))
for i in range (1, 11):
  print(f"{numero} x {i} = {numero * i}")
# Out:
# digite um numero: 10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100
