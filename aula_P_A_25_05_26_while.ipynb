# %% [markdown]
# <a href="https://colab.research.google.com/github/ericcsilva/PA-1-C-grupo-A/blob/main/aula_P_A_25_05_26_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# laços e interaçoes

senha = ' '

while senha != 1234

  senha = int (input(Digite sua senha : ))

# %%
# contagem de 0 ate 5
for i in range (6):
  print (i)

# %%
contador = 0

while contador <= 5:
  print (contador)
  contador += 1

# %%
contador = 5

while contador >= 0:
  print(contador)
  contador =1

# %%
# calculadora simples - escrever um programa que calcula as 04 operações matemáticas

# opção 1 - somar
# opção 2 - subtrair
# opção 3 - multiplicar
# opção 4 - dividir
# opção 5 - sair

opção = " "
a = 0
b = 0

print ("--------- MENU ---------")
print (" ")

print ("opção 1 - somar")
print ("opção 2 - subtrair")
print ("opção 3 - multiplicar")
print ("opção 4 - dividir")
print ("opção 5 - sair")
print ("====================")
print (" ")

try:

  while opção != 5:
    opção = int (input("digite a opção desejada ou 5 para sair: "))

    if opção <= 0 or opção >= 6:
      print ("digite uma opção de 1 a 4 ou 5 para sair!")

    elif opção == 1:
      a = float (input("digite o primeiro número: "))
      b = float (input("digite o segundo número: "))

      print(f"total da soma de {a} + {b} é igual: {a + b}")
      print(" ")

    elif opção == 2:
      a = float (input("digite o primeiro número: "))
      b = float (input("digite o segundo número: "))

      print(f"total da subtração de {a} - {b} é igual: {a - b}")
      print(" ")

    elif opção == 3:
      a = float (input("digite o primeiro número: "))
      b = float (input("digite o segundo número: "))

      print(f"total da multiplicação de {a} * {b} é igual: {a * b}")
      print(" ")

    elif opção == 4:
      a = float (input("digite o primeiro número: "))
      b = float (input("digite o segundo número: "))

      print(f"total da divisão de {a} / {b} é igual: {a / b}")
      print(" ")

except:
  print("digite apenas números de 01 á 05!")
# Out:
# --------- MENU ---------
#
# opção 1 - somar
# opção 2 - subtrair
# opção 3 - multiplicar
# opção 4 - dividir
# opção 5 - sair
# ====================
#
# digite a opção desejada ou 5 para sair: 4
# digite o primeiro número: 5
# digite o segundo número: 6
# total da divisão de 5.0 / 6.0 é igual: 0.8333333333333334
#
# digite a opção desejada ou 5 para sair: 5

# %%
nota1 = float (input("digite a nota do 1º bimestre: "))
nota2 = float (input("digite a nota do 2º bimestre: "))
nota3 = float (input("digite a nota do 3º bimestre: "))
nota4 = float (input("digite a nota do 4º bimestre: "))

media = (nota1 + nota2 + nota3 + nota4) / 4

if media >= 7:

  print (f"voce foi aprovado, sua media foi : {media}")

elif media >= 5:

   print (f"voce esta de recuperaçao, sua media foi : {media}")

else:

   print ("voce foi reprovado, sua media foi: ")
# Out:
# digite a nota do 1º bimestre1
# digite a nota do 2º bimestre10
# digite a nota do 3º bimestre4
# digite a nota do 4º bimestre6
# voce esta de recuperaçao, sua media foi : 5.25
