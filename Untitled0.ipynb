# %% [markdown]
# <a href="https://colab.research.google.com/github/ericcsilva/PA-1-C-grupo-A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tipos Numericos
idade = 14 # int
altura = 1.75 # float
numero_complexo = 2 + 3j # complex

# tipo booleano
esta_chovendo = False # bool

# %%
# Entrada
lado = 6
quadrado = lado * lado
# Saída
print (f"Total da área do quadrado: {quadrado}" )
# Out:
# Total da área do quadrado: 36

# %%
# Entrada
altura = 86
comprimento = 12
# Procesamento
sala_de_aula =altura * comprimento
# Saída
print (f"Total da área do sala_de_aula: {sala_de_aula}" )
# Out:
# Total da área do sala_de_aula: 1032

# %%
# Entrada
nota_1= 2
nota_2 = 3
nota_3 = 4
nota_4 = 5
# Processamento
media = (nota_1 + nota_2 + nota_3 + nota_4) /4
# Saída
print(media)
# Out:
# 3.5

# %%
# Entrada
numero = 12

#processamento

dobro = numero * 2
#Saida
print (dobro)
# Out:
# 24
