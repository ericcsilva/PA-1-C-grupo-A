# %% [markdown]
# <a href="https://colab.research.google.com/github/ericcsilva/PA-1-C-grupo-A/blob/main/else_e_if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int (input("Digite um número: "))
b  = int (input("Digite um número: "))

if a > b:
     print(f"{a}maior que {b}>")

else:8
    print(f"{b}maior que {a}>")
# Out:
# Digite um número: 9
# Digite um número: 0
# 9maior que 0>

# %%
nome = str (input("Digite seu nome: "))
idade = int  (input("Digite sua idade: "))

if idade> 18:

    print (f"{nome}, voce é menor de idade")

else:
    print (f"{nome}, voce é menor de idade")
# Out:
# Digite seu nome: eric
# Digite sua idade: 14
# eric, voce é menor de idade

# %%
numero = int (input("Digite um numero: "))

divisao = numero % 2
if divisao == 0:
  print("numero é par")

else:
  print("numero é impar")
# Out:
# Digite um numero: 7
# numero é impar

# %%
senha = int (input("Digite sua senha"))

if senha == 1234:
  print("acesso permitido")

else:
  print("acesso negado, digite novamente")
# Out:
# Digite sua senha9191
# acesso negado, digite novamente

# %%
numero = int  (input("Digite um numero: "))

if numero> 10:

    print (f"{numero}, esse numero e maior que 10")

else:
    print (f"{numero}, esse numero e menor que 10")
# Out:
# Digite um numero: 2
# 2, esse numero e menor que 10

# %%
valor = int (input("digite o valor da compra"))

if valor > 100:
    print (f"{valor}, recebeu um desconto de 10%")
else:
    print (f"o valor é {valor}")
# Out:
# digite o valor da compra120
# 120, recebeu um desconto de 10%

# %%
compra = float(input("digite o valor da compra: ").replace(',', '.'))

if compra > 100 :
  desconto = compra * 0.9
  print (desconto)

else:
  print (compra)
# Out:
# digite o valor da compra: 100,55
# 90.495

# %%
nota1 = float (input("digite a nota do 1º bimestre"))
nota2 = float (input("digite a nota do 2º bimestre"))
nota3 = float (input("digite a nota do 3º bimestre"))
nota4 = float (input("digite a nota do 4º bimestre"))

media = (nota1 + nota2 + nota3 + nota4) / 4

if media >= 7:

  print (f"voce foi aprovado, sua media foi : {media}")

elif media >= 5:

   print (f"voce esta de recuperçao, sua media foi : {media}")

else:

   print ("voce foi reprovado, sua media foi: ")
# Out:
# digite a nota do 1º bimestre9
# digite a nota do 2º bimestre3
# digite a nota do 3º bimestre5
# digite a nota do 4º bimestre7
# voce esta de recuperçao, sua media foi : 6.0
